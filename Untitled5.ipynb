# %% [markdown]
# <a href="https://colab.research.google.com/github/Radiation444/DSA-Project/blob/master/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import networkx

# %%
networkx.draw()

# %% [markdown]
# # Task
# Extract a graph from a text file named "graph.txt" using the `networkx` library.

# %% [markdown]
# ## Load the text file
#
# ### Subtask:
# Read the text file into a format that can be easily processed.

# %% [markdown]
# **Reasoning**:
# Read the content of the file into a string.

# %%
with open("graph.txt", "r") as f:
    graph_string = f.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3325454777.py in <cell line: 0>()
# ----> 1 with open("graph.txt", "r") as f:
#       2     graph_string = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'graph.txt'
